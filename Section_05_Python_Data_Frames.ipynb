# %%
import pandas as pd #now we want to work with dataframes; similar to excel tables. Pandas is similar to the way dataframes
                    #work in R
                    # pd.read_csv make sure you are using a .csv file

# %%
# Method 1: Specify full path to file. Entire file pathway

# %%
#windows
stats = pd.read_csv('C:\\Users\\aaufdencamp\\PythonA-Z_DataScience\\Section_05_Python_A-Z\\P4-Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Method 2: Change Working Directory. Establish file path update the folder you want to pull from. Call a specific file from 
# that folder as needed

# %%
import os

# %%
print(os.getcwd()) # discover where Jupyter goes to access a file when called
# Out:
# C:\Users\aaufdencamp\PythonA-Z_DataScience\Section_05_Python_A-Z

# %%
#windows
os.chdir('C:\\Users\\aaufdencamp\\PythonA-Z_DataScience\\Section_05_Python_A-Z') #update or change where Jupyter goes to access a file when called

# %%
print(os.getcwd())
# Out:
# C:\Users\aaufdencamp\PythonA-Z_DataScience\Section_05_Python_A-Z

# %%
stats2 = pd.read_csv('P4-Demographic-Data.csv')

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
###Exploring Your Data
#1. Full dataframe
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
###Exploring Your Data
#2. number of rows
len(stats) #as a matter of course and traceability purposes always check number of rows are imported
# Out:
# 195

# %%
###Exploring Your Data
#3. See columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
###Exploring Your Data
#4. number of columns
len(stats.columns)
# Out:
# 5

# %%
###Exploring Your Data
#5. top rows
stats.head() #remember the brackets. Default is 5, but you can input an argument to change the number of rows returned
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#6. bottom rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#7. info on the columns
stats.info() #like the str function in R (where categorical variables are called factors)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8 get the stats on the columns which have numeric data in them.
stats.describe()  #similar to R's summary() function
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
#re-name columns
#NOTE: in Jupyter we can just enter to create a new line of code within  a cell
# But in Python iteslf you need a backslash within a cell to "enter" a new line of code

# %%
stats.columns = ['CountryName', 'CountryCode',
                 'Birthrate', 'Internetusers','IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
###subsetting dataframes in Pandas for Python because we are using a Pandas package here

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
##Part One- Subset by Rows
# dataframes and tables are typically constructed with column headers and the rows are
# a new instance (individual) of corresponding data. Python is biased to subset by row

# %%
stats[21:26] # We can call rows 21 - 25 as such becuase of the Python bias to subset by row
# Out:
#    CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income
# 23     Bolivia         BOL     24.236          36.94  Lower middle income
# 24      Brazil         BRA     14.931          51.04  Upper middle income
# 25    Barbados         BRB     12.188          73.00          High income

# %%
stats[:] # We can call every row as such because of Python bias to subset by row
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[185:]
# Out:
#                CountryName CountryCode  Birthrate  Internetusers  \
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
# 189                  Samoa         WSM     26.172           15.3
# 190            Yemen, Rep.         YEM     32.947           20.0
# 191           South Africa         ZAF     20.850           46.5
# 192       Congo, Dem. Rep.         COD     42.394            2.2
# 193                 Zambia         ZMB     40.471           15.4
# 194               Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# ...

# %%
stats[:10]
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
#Quick exercise: reverse the dataframe

# %%
stats[ : : -1 ] #start at beginning : go to end : reverse step -1
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
#stats = stats[ : : -1 ] #if you want to actually modify the acutal dataframe to be reverse order, you have to set it equal to

# %%
stats[ : : -1 ]
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
stats = stats[ : : -1 ]

# %%
#get only every 20th row
stats[ 20: : 20]
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 174   Trinidad and Tobago         TTO     14.590          63.80
# 154          Sierra Leone         SLE     36.729           1.70
# 134                  Oman         OMN     20.419          66.45
# 114        Macedonia, FYR         MKD     11.222          65.24
# 94               Kiribati         KIR     29.044          11.50
# 74   Hong Kong SAR, China         HKG      7.900          74.20
# 54                Estonia         EST     10.300          79.40
# 34          Cote d'Ivoire         CIV     37.320           8.40
# 14           Burkina Faso         BFA     40.551           9.10
#
#              IncomeGroup
# 174          High income
# 154           Low income
# 134          High income
# 114  Upper middle income
# 94   Lower middle income
# 74           High income
# 54           High income
# 34   Lower middle income
# 14            Low income

# %%
#Part Two: subsetting by Columns

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.head
# Out:
# <bound method NDFrame.head of               CountryName CountryCode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ...

# %%
stats['CountryName'] #to extract just CountyName columns
# Out:
# 194                Zimbabwe
# 193                  Zambia
# 192        Congo, Dem. Rep.
# 191            South Africa
# 190             Yemen, Rep.
#                ...
# 4      United Arab Emirates
# 3                   Albania
# 2                    Angola
# 1               Afghanistan
# 0                     Aruba
# Name: CountryName, Length: 195, dtype: object

# %%
stats['CountryName'].head()
# Out:
# 194            Zimbabwe
# 193              Zambia
# 192    Congo, Dem. Rep.
# 191        South Africa
# 190         Yemen, Rep.
# Name: CountryName, dtype: object

# %%
#to call more than one column from a datafram you pass them in as a list, and it will return a table.

#comparing to R: in R you would pass a vector: c('CountryName', 'BirthRate')

stats[['CountryName', 'Birthrate']]
# Out:
#               CountryName  Birthrate
# 194              Zimbabwe     35.715
# 193                Zambia     40.471
# 192      Congo, Dem. Rep.     42.394
# 191          South Africa     20.850
# 190           Yemen, Rep.     32.947
# ..                    ...        ...
# 4    United Arab Emirates     11.044
# 3                 Albania     12.877
# 2                  Angola     45.985
# 1             Afghanistan     35.253
# 0                   Aruba     10.244
#
# [195 rows x 2 columns]

# %%
stats[['Birthrate', 'CountryName']] #You can order columns differently.
# Out:
#      Birthrate           CountryName
# 194     35.715              Zimbabwe
# 193     40.471                Zambia
# 192     42.394      Congo, Dem. Rep.
# 191     20.850          South Africa
# 190     32.947           Yemen, Rep.
# ..         ...                   ...
# 4       11.044  United Arab Emirates
# 3       12.877               Albania
# 2       45.985                Angola
# 1       35.253           Afghanistan
# 0       10.244                 Aruba
#
# [195 rows x 2 columns]

# %%
#Tip for Qucik Access - recquire the name to be one word (no spaces). We can dispense with brackets and just use "." + Columnname
# and you can only do it for one column

# %%
stats['Birthrate']
# Out:
# 194    35.715
# 193    40.471
# 192    42.394
# 191    20.850
# 190    32.947
#         ...
# 4      11.044
# 3      12.877
# 2      45.985
# 1      35.253
# 0      10.244
# Name: Birthrate, Length: 195, dtype: float64

# %%
stats.Birthrate #in R you call stats$Birthrate
# Out:
# 194    35.715
# 193    40.471
# 192    42.394
# 191    20.850
# 190    32.947
#         ...
# 4      11.044
# 3      12.877
# 2      45.985
# 1      35.253
# 0      10.244
# Name: Birthrate, Length: 195, dtype: float64

# %%
stats.Birthrate.head()
# Out:
# 194    35.715
# 193    40.471
# 192    42.394
# 191    20.850
# 190    32.947
# Name: Birthrate, dtype: float64

# %%
#Part3. Combining

# %%
stats[4:8][['CountryName', 'Birthrate']] #here we are doing two subsets at once
# Out:
#             CountryName  Birthrate
# 190         Yemen, Rep.     32.947
# 189               Samoa     26.172
# 188  West Bank and Gaza     30.394
# 187             Vanuatu     26.739

# %%
df1= stats[4:8] #subset one

# %%
df1
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 190         Yemen, Rep.         YEM     32.947           20.0
# 189               Samoa         WSM     26.172           15.3
# 188  West Bank and Gaza         PSE     30.394           46.6
# 187             Vanuatu         VUT     26.739           11.3
#
#              IncomeGroup
# 190  Lower middle income
# 189  Lower middle income
# 188  Lower middle income
# 187  Lower middle income

# %%
df1[['CountryName', 'Birthrate']] #subset two
# Out:
#             CountryName  Birthrate
# 190         Yemen, Rep.     32.947
# 189               Samoa     26.172
# 188  West Bank and Gaza     30.394
# 187             Vanuatu     26.739

# %%
stats[['CountryName', 'Birthrate']] #we can even reverse the order of the subsets and get the same thing because Python 
#is biased to subsetting rows using ration notation and subsetting columns using list notation
# Out:
#               CountryName  Birthrate
# 194              Zimbabwe     35.715
# 193                Zambia     40.471
# 192      Congo, Dem. Rep.     42.394
# 191          South Africa     20.850
# 190           Yemen, Rep.     32.947
# ..                    ...        ...
# 4    United Arab Emirates     11.044
# 3                 Albania     12.877
# 2                  Angola     45.985
# 1             Afghanistan     35.253
# 0                   Aruba     10.244
#
# [195 rows x 2 columns]

# %%
stats[['CountryName', 'Birthrate']][4:8]
# Out:
#             CountryName  Birthrate
# 190         Yemen, Rep.     32.947
# 189               Samoa     26.172
# 188  West Bank and Gaza     30.394
# 187             Vanuatu     26.739

# %%
###Basic Operations with dataframes

# %%
#Already spoke about subsetting. Refresh:

# %%
stats.head()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income

# %%
stats[['CountryCode','Birthrate', 'Internetusers']][4:8]
# Out:
#     CountryCode  Birthrate  Internetusers
# 190         YEM     32.947           20.0
# 189         WSM     26.172           15.3
# 188         PSE     30.394           46.6
# 187         VUT     26.739           11.3

# %%
#Mathematical operations:
result = stats.Birthrate *stats.Internetusers

# %%
result.head() #Python knows to multiply element by element (row x row of the called Columns) (similar to how R does)
# Out:
# 194    660.7275
# 193    623.2534
# 192     93.2668
# 191    969.5250
# 190    658.9400
# dtype: float64

# %%
#Add a column:
stats['MyCalc'] = stats.Birthrate * stats.Internetusers
# Out:
# C:\Users\aaufdencamp\AppData\Local\Temp\ipykernel_27544\291720898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stats['MyCalc'] = stats.Birthrate * stats.Internetusers

# %%
stats #notice we have added a column MyCalc
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup    MyCalc
# 194           Low income  660.7275
# 193  Lower middle income  623.2534
# 192           Low income   93.2668
# 191  Upper middle income  969.5250
# ...

# %%
#removing a column

# %%
stats.head()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup    MyCalc
# 194           Low income  660.7275
# 193  Lower middle income  623.2534
# 192           Low income   93.2668
# 191  Upper middle income  969.5250
# 190  Lower middle income  658.9400

# %%
stats.drop('MyCalc', axis = 1) #by default .drop drops rows, ie axis = 0. use shift + tab to get information on the method. use 
                            # axis = 1 to drop columns
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
stats.head()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup    MyCalc
# 194           Low income  660.7275
# 193  Lower middle income  623.2534
# 192           Low income   93.2668
# 191  Upper middle income  969.5250
# 190  Lower middle income  658.9400

# %%
stats = stats.drop('MyCalc', axis = 1, inplace = False) #use inplace = False to acutally drop from the datafram; default is inplace = True

# %%
#Note: Python does not recycle lists if they are shorter than the row lengths of your data frame like R does

# %%
####Filtering Data Frames -- a lot of data science is using filtering and subsetting

# %%
#Filtering is about Rows

# %%
stats.head()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income

# %%
stats.Internetusers < 2 #Boolean for selecting for Internetusers group where less than 2 use the internet. 
                         #THis is wrt percent of population
# Out:
# 194    False
# 193    False
# 192    False
# 191    False
# 190    False
#        ...
# 4      False
# 3      False
# 2      False
# 1      False
# 0      False
# Name: Internetusers, Length: 195, dtype: bool

# %%
Filter = stats.Internetusers < 2

# %%
Filter #we need the object called filter to tell Python which rows to extract!
# Out:
# 194    False
# 193    False
# 192    False
# 191    False
# 190    False
#        ...
# 4      False
# 3      False
# 2      False
# 1      False
# 0      False
# Name: Internetusers, Length: 195, dtype: bool

# %%
stats[Filter] #Python knows we want rows where internetusers < 2 
             #conceptually this is just like R
# Out:
#       CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
# 156       Somalia         SOM     43.891            1.5           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 127         Niger         NER     49.661            1.7           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 64         Guinea         GIN     37.337            1.6           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 11        Burundi         BDI     44.151            1.3           Low income

# %%
Filter2 = stats.Birthrate > 40

# %%
stats[Filter2] #Birthrate is in terms of # of children born for every 1,000 people.
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 178            Uganda         UGA     43.474           16.2
# 167              Chad         TCD     45.745            2.3
# 156           Somalia         SOM     43.891            1.5
# 128           Nigeria         NGA     40.045           38.0
# 127             Niger         NER     49.661            1.7
# 115              Mali         MLI     44.138            3.5
# 65        Gambia, The         GMB     42.525           14.0
# 14       Burkina Faso         BFA     40.551            9.1
# 11            Burundi         BDI     44.151            1.3
# 2              Angola         AGO     45.985           19.1
#
#              IncomeGroup
# 193  Lower middle income
# 192           Low income
# 178           Low income
# 167           Low income
# 156           Low income
# 128  Lower middle income
# ...

# %%
# we don't need to name a variable and assign it to the filter logic. We can simply pass the filter logic into to the 
# bracket slicing notation
stats[stats.Birthrate > 40]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 178            Uganda         UGA     43.474           16.2
# 167              Chad         TCD     45.745            2.3
# 156           Somalia         SOM     43.891            1.5
# 128           Nigeria         NGA     40.045           38.0
# 127             Niger         NER     49.661            1.7
# 115              Mali         MLI     44.138            3.5
# 65        Gambia, The         GMB     42.525           14.0
# 14       Burkina Faso         BFA     40.551            9.1
# 11            Burundi         BDI     44.151            1.3
# 2              Angola         AGO     45.985           19.1
#
#              IncomeGroup
# 193  Lower middle income
# 192           Low income
# 178           Low income
# 167           Low income
# 156           Low income
# 128  Lower middle income
# ...

# %%
stats[stats.Birthrate > 40 and stats.Internetusers < 2 ] #ERROR
#Python is not a vectorized language. The boolean and is trying to work with two single values on either side of the 
# boolean symbol; while in reality on BOTH sides of the logic symbols are lists of True and False -- not single values
# in Python we need to use the ampersand & bitwise operator and use bracket notation to help Python understand order of ops
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27544\2030220537.py in ?()
# ----> 1 stats[stats.Birthrate > 40 and stats.Internetusers < 2 ] #ERROR
#       2 #Python is not a vectorized language. The boolean and is trying to work with two single values on either side of the
#       3 # boolean symbol; while in reality on BOTH sides of the logic symbols are lists of True and False -- not single values
#       4 # in Python we need to use the ampersand & bitwise operator and use bracket notation to help Python understand order of ops
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
stats[(stats.Birthrate > 40) & (stats.Internetusers < 2) ]
# Out:
#     CountryName CountryCode  Birthrate  Internetusers IncomeGroup
# 156     Somalia         SOM     43.891            1.5  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 11      Burundi         BDI     44.151            1.3  Low income

# %%
stats.head()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income

# %%
stats[stats.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  Birthrate  Internetusers  IncomeGroup
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 181          United States         USA     12.500          84.20  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# ..                     ...         ...        ...            ...          ...
# 8                Australia         AUS     13.200          83.00  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 0                    Aruba         ABW     10.244          78.90  High income
#
# [67 rows x 5 columns]

# %%
#how to get the unique categories of categorical variables with more multiple levels
stats.IncomeGroup.unique()
# Out:
# array(['Low income', 'Lower middle income', 'Upper middle income',
#        'High income'], dtype=object)

# %%
stats[stats.CountryName == 'Malta']
# Out:
#     CountryName CountryCode  Birthrate  Internetusers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
###Accessing individual elements
stats[2,2] #error.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 2)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 2
# ...

# %%
stats.head()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income

# %%
stats = stats[: : -1]

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# we need two functions to access indiviudal elements.
# .at  # .at is for labels. Important: even integers are treated as labels. It looks at labels. Labels are the column header
       # and row labels

# .iat # .iat is for integer location; that is, the function literally counts row x column to return the cell you request

# %%
stats.iat[3,4] #return cell at row 3, column 4
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[2,'Birthrate']
# Out:
# 45.985

# %%
#why we need .at:

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]  #.iat literally counts to get to the cell requested.
# Out:
# 'Libya'

# %%
sub10.at[10, 'CountryName']  #.at looks for labels. It does not care about sequence. That is why there are differnt results
# Out:
# 'Azerbaijan'

# %%
#Intro to Seaborn: a visualization package in Python that builds on matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Distribution
vis1 = sns.distplot(stats['Internetusers'], bins = 30) # recall that shift + tab will open up a reference section about
                                                        #the functon

# %%
#Boxplots:
vis2 = sns.boxplot(data = stats, x = "IncomeGroup", y = "Birthrate")

# %%
#Seaborn gallery https://seaborn.pydata.org/examples/index.html

# %%
#Initially there was a line of best fit because fit_reg = True is default. We changed it to False because visually
# the data is very spread from the line of best fit. Their appears to be a negative relation ship 
#

# %%
vis3 = sns.lmplot(data=stats, x= 'Internetusers', y ='Birthrate',\
                  fit_reg = False, hue = 'IncomeGroup' )  #linear model plot

# %%
# a facet grids take up a lot of space and have their own parameter to change their size.

# %%
##Keyword arguments in Python

# %%
#marker size: when you hit shit + tab to see how to change marker size we see there is not explicit parameter.
# so there is a parameter we want to lookup in seaborn.lmplot. 
# {scatter,line}_kws : dictionaries
    #Additional keyword arguments to pass to ``plt.scatter`` and
    #``plt.plot``. 
    # https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot
#Seaborn relies on matplotlib. 
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter
# So there are other parameters in pyplot that are not in the parameter list of the seaborn function.

# %%
vis3 = sns.lmplot(data=stats, x= 'Internetusers', y ='Birthrate',\
                  fit_reg = False, hue = 'IncomeGroup', \
                  scatter_kws={'s':100})

# %%
stats[195:189:-1][::-1]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.tail()
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats[190:195]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats[190:]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
